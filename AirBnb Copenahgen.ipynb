# %%
import pandas as pd
import numpy as np

# %%
#import os

# file path
listings = pd.read_csv("airbnb_cph_listings.csv")
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26334 entries, 0 to 26333
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(25), int64(21), object(60)
# memory usage: 21.3+ MB
# C:\Users\Muskanstha\.conda\envs\datascience\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.options.display.max_columns = None
display(listings.head())
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   6983   https://www.airbnb.com/rooms/6983  20190217154948   2019-02-17
# 1  26057  https://www.airbnb.com/rooms/26057  20190217154948   2019-02-17
# 2  26473  https://www.airbnb.com/rooms/26473  20190217154948   2019-02-17
# 3  29118  https://www.airbnb.com/rooms/29118  20190217154948   2019-02-17
# 4  29618  https://www.airbnb.com/rooms/29618  20190217154948   2019-02-17
#
#                                                 name  \
# 0                               Copenhagen 'N Livin'
# 1                Lovely house - most attractive area
# 2          City Centre Townhouse Sleeps 1-12 persons
# 3                    Best Location in Cool Istedgade
# 4  Artsy and familyfriendly home in lovely Copenh...
#
#                                              summary  \
# 0  Lovely apartment located in the hip Nørrebro a...
# 1  Our lovely house in the center of the city is ...
# ...

# %%
listings.columns.values
# Out:
# array(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'access',
#        'interaction', 'house_rules', 'thumbnail_url', 'medium_url',
#        'picture_url', 'xl_picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode',
#        'market', 'smart_location', 'country_code', 'country', 'latitude',
# ...

# %%
columns_to_keep = [ 'host_since', 'host_response_time', 'host_response_rate', 'host_is_superhost', 'host_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood_cleansed', 'is_location_exact', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'security_deposit', 'square_feet', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'first_review', 'last_review', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'requires_license', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 'reviews_per_month' ]
df = listings[columns_to_keep]
df.head()
# Out:
#    host_since  host_response_time host_response_rate host_is_superhost  \
# 0  2009-05-12        within a day               100%                 t
# 1  2010-04-17  within a few hours               100%                 t
# 2  2010-04-22      within an hour               100%                 f
# 3  2010-05-15  within a few hours               100%                 f
# 4  2010-05-18                 NaN                NaN                 f
#
#    host_listings_count                                 host_verifications  \
# 0                  1.0                      ['email', 'phone', 'reviews']
# 1                  1.0  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 2                  3.0  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 3                  1.0                      ['email', 'phone', 'reviews']
# 4                  1.0  ['email', 'phone', 'facebook', 'reviews', 'jum...
#
#   host_has_profile_pic host_identity_verified     neighbourhood_cleansed  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26334 entries, 0 to 26333
# Data columns (total 46 columns):
# host_since                          26324 non-null object
# host_response_time                  11460 non-null object
# host_response_rate                  11460 non-null object
# host_is_superhost                   26324 non-null object
# host_listings_count                 26324 non-null float64
# host_verifications                  26334 non-null object
# host_has_profile_pic                26324 non-null object
# host_identity_verified              26324 non-null object
# neighbourhood_cleansed              26334 non-null object
# is_location_exact                   26334 non-null object
# accommodates                        26334 non-null int64
# bathrooms                           26317 non-null float64
# bedrooms                            26324 non-null float64
# beds                                26313 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# host_since                             10
# host_response_time                  14874
# host_response_rate                  14874
# host_is_superhost                      10
# host_listings_count                    10
# host_verifications                      0
# host_has_profile_pic                   10
# host_identity_verified                 10
# neighbourhood_cleansed                  0
# is_location_exact                       0
# accommodates                            0
# bathrooms                              17
# bedrooms                               10
# beds                                   21
# bed_type                                0
# amenities                               0
# security_deposit                    13498
# square_feet                         25905
# cleaning_fee                         8538
# guests_included                         0
# extra_people                            0
# minimum_nights                          0
# ...

# %%
df.describe()
# Out:
#        host_listings_count  accommodates     bathrooms      bedrooms  \
# count         26324.000000  26334.000000  26317.000000  26324.000000
# mean              4.019564      3.306600      1.067542      1.544826
# std              25.418383      1.620494      0.274346      0.873448
# min               0.000000      1.000000      0.000000      0.000000
# 25%               1.000000      2.000000      1.000000      1.000000
# 50%               1.000000      3.000000      1.000000      1.000000
# 75%               1.000000      4.000000      1.000000      2.000000
# max             256.000000     16.000000     10.000000      8.000000
#
#                beds  square_feet  guests_included  minimum_nights  \
# count  26313.000000   429.000000     26334.000000    26334.000000
# mean       2.175275   692.731935         1.521569        3.618440
# std        1.524997   572.336281         1.054639       15.644449
# min        0.000000     0.000000         1.000000        1.000000
# ...
